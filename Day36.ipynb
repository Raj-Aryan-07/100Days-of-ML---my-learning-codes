# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df= pd.read_csv(r"D:\ML\DataSet\titanic_toy_day36.csv")

# %%
df.head()
# Out:
#     Age     Fare  Family  Survived
# 0  22.0   7.2500       1         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       0         1
# 3  35.0  53.1000       1         1
# 4  35.0   8.0500       0         0

# %% [markdown]
# ---------------
# these are when I  change the original dataset

# %%
# df['Family'] = df['SibSp']+df['Parch']
# df.sample()

# %%
# # Select only your 4 specific columns and arrange them in this exact order
# df = df[['Age', 'Fare', 'Family','Survived']]

# # View a random row to check the new structure
# df.sample()

# %%
# df.head()

# %% [markdown]
# ----------------------------

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       714 non-null    float64
#  1   Fare      846 non-null    float64
#  2   Family    891 non-null    int64
#  3   Survived  891 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 28.0 KB

# %%
df.isnull().mean()      #this will give that out of one how many is null on a average.
# Out:
# Age         0.198653
# Fare        0.050505
# Family      0.000000
# Survived    0.000000
# dtype: float64

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.shape,y_train.shape,X_test.shape
# Out:
# ((712, 3), (712,), (179, 3))

# %%
X_train.isnull().mean()     #this will give me the percentage of the missing values in each columns
# Out:
# Age       0.207865
# Fare      0.050562
# Family    0.000000
# dtype: float64

# %%
mean_age = X_train['Age'].mean()
median_age = X_train['Age'].median()

mean_fare = X_train['Fare'].mean()
median_fare = X_train['Fare'].median()

# %%
X_train['age_mean'] = X_train['Age'].fillna(mean_age)
X_train['age_median'] = X_train['Age'].fillna(median_age)

X_train['fare_mean'] = X_train['Fare'].fillna(mean_fare)
X_train['fare_median'] = X_train['Fare'].fillna(median_fare)

# %%
X_train.sample(5)
# Out:
#       Age     Fare  Family   age_mean  age_median  fare_mean  fare_median
# 526  50.0  10.5000       0  50.000000       50.00    10.5000      10.5000
# 699  42.0   7.6500       0  42.000000       42.00     7.6500       7.6500
# 651  18.0  23.0000       1  18.000000       18.00    23.0000      23.0000
# 295   NaN  27.7208       0  29.785904       28.75    27.7208      27.7208
# 358   NaN   7.8792       0  29.785904       28.75     7.8792       7.8792

# %%
print('Original Age variable variance : ', X_train['Age'].var())
print('Age Variance after mean imputation : ', X_train['age_mean'].var())
print('Age Variance after median imputation : ', X_train['age_median'].var())

print('Original Fare variable variance : ', X_train['Fare'].var())
print('Fare Variance after mean imputation : ', X_train['fare_mean'].var())
print('Fare Variance after median imputation : ', X_train['fare_median'].var())


#when we replace the missing values with mean or median then the variance decreases as more of the values comes towards mean, so deviation decreases
# Out:
# Original Age variable variance :  204.34951339046142
# Age Variance after mean imputation :  161.81262452718676
# Age Variance after median imputation :  161.98956633460548
# Original Fare variable variance :  2448.1979137063163
# Fare Variance after mean imputation :  2324.2385256705534
# Fare Variance after median imputation :  2340.09102197536

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
X_train['Age'].plot(kind='kde', ax=ax)

# variable imputed with the median
X_train['age_median'].plot(kind='kde', ax=ax, color='red')

# variable imputed with the mean
X_train['age_mean'].plot(kind='kde', ax=ax, color='green')

# add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
X_train['Fare'].plot(kind='kde', ax=ax)

# variable imputed with the median
X_train['fare_median'].plot(kind='kde', ax=ax, color='red')

# variable imputed with the mean
X_train['fare_mean'].plot(kind='kde', ax=ax, color='green')

# add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
X_train.cov()       #this is covariance - this tells about column's interaction with other columns
# Out:
#                     Age         Fare     Family    age_mean  age_median  \
# Age          204.349513    70.719262  -6.498901  204.349513  204.349513
# Fare          70.719262  2448.197914  17.258917   55.603719   57.957599
# Family        -6.498901    17.258917   2.735252   -5.146106   -5.112563
# age_mean     204.349513    55.603719  -5.146106  161.812625  161.812625
# age_median   204.349513    57.957599  -5.112563  161.812625  161.989566
# fare_mean     66.665205  2448.197914  16.385048   52.788341   55.023037
# fare_median   64.858859  2448.197914  16.476305   51.358000   53.553455
#
#                fare_mean  fare_median
# Age            66.665205    64.858859
# Fare         2448.197914  2448.197914
# Family         16.385048    16.476305
# age_mean       52.788341    51.358000
# age_median     55.023037    53.553455
# fare_mean    2324.238526  2324.238526
# fare_median  2324.238526  2340.091022

# %%
X_train.corr()
# Out:
#                   Age      Fare    Family  age_mean  age_median  fare_mean  \
# Age          1.000000  0.092644 -0.299113  1.000000    1.000000   0.090156
# Fare         0.092644  1.000000  0.208268  0.088069    0.091757   1.000000
# Family      -0.299113  0.208268  1.000000 -0.244610   -0.242883   0.205499
# age_mean     1.000000  0.088069 -0.244610  1.000000    0.999454   0.086078
# age_median   1.000000  0.091757 -0.242883  0.999454    1.000000   0.089673
# fare_mean    0.090156  1.000000  0.205499  0.086078    0.089673   1.000000
# fare_median  0.087356  1.000000  0.205942  0.083461    0.086982   0.996607
#
#              fare_median
# Age             0.087356
# Fare            1.000000
# Family          0.205942
# age_mean        0.083461
# age_median      0.086982
# fare_mean       0.996607
# fare_median     1.000000

# %%
X_train[['Age', 'age_median', 'age_mean']].boxplot()

#this tells us that in this case , the no. of outliers have increased significantly after making the changes in the missing values
#here, mainly the outliers are increased as th einter-quartile range is decreased
# Out:
# <Axes: >

# %%
X_train[['Fare', 'fare_median', 'fare_mean']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# -----------
# -----------
# ## Usin Sklearn

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
imputer1 = SimpleImputer(strategy='median')
imputer2 = SimpleImputer(strategy='mean')

# %%
trf = ColumnTransformer([
    ('imputer1',imputer1,['Age']),
    ('imputer2',imputer2,['Fare'])
],remainder='passthrough')

# %%
trf.fit(X_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('imputer1', SimpleImputer(strategy='median'),
#                                  ['Age']),
#                                 ('imputer2', SimpleImputer(), ['Fare'])])

# %%
trf.named_transformers_['imputer1'].statistics_
# Out:
# array([28.75])

# %%
trf.named_transformers_['imputer2'].statistics_
# Out:
# array([32.61759689])

# %%
X_train = trf.transform(X_train)
X_test = trf.transform(X_test)

# %%
X_train
# Out:
# array([[ 40.    ,  27.7208,   0.    ],
#        [  4.    ,  16.7   ,   2.    ],
#        [ 47.    ,   9.    ,   0.    ],
#        ...,
#        [ 71.    ,  49.5042,   0.    ],
#        [ 28.75  , 221.7792,   0.    ],
#        [ 28.75  ,  25.925 ,   0.    ]], shape=(712, 3))

# %% [markdown]
# -----------------
# --------------------
# --------------------
# -----------------------

# %% [markdown]
# # Arbitrary Value Implementation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df1= pd.read_csv(r"D:\ML\DataSet\titanic_toy_day36.csv")

# %%
df1.head()
# Out:
#     Age     Fare  Family  Survived
# 0  22.0   7.2500       1         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       0         1
# 3  35.0  53.1000       1         1
# 4  35.0   8.0500       0         0

# %%
df1.isnull().mean()
# Out:
# Age         0.198653
# Fare        0.050505
# Family      0.000000
# Survived    0.000000
# dtype: float64

# %%
X1 = df1.drop(columns=['Survived'])
y1 = df1['Survived']

# %%
X1_train,X1_test,y1_train,y1_test = train_test_split(X1,y1,test_size=0.2,random_state=2)

# %%
X1_train['Age_99'] = X1_train['Age'].fillna(99)
X1_train['Age_minus1'] = X1_train['Age'].fillna(-1)

X1_train['Fare_999'] = X1_train['Fare'].fillna(999)
X1_train['Fare_minus1'] = X1_train['Fare'].fillna(-1)

# %%
print('Original Age variable variance: ', X1_train['Age'].var())
print('Age Variance after 99 wala imputation: ', X1_train['Age_99'].var())
print('Age Variance after -1 wala imputation: ', X1_train['Age_minus1'].var())

print('Original Fare variable variance: ', X1_train['Fare'].var())
print('Fare Variance after 999 wala imputation: ', X1_train['Fare_999'].var())
print('Fare Variance after -1 wala imputation: ', X1_train['Fare_minus1'].var())
# Out:
# Original Age variable variance:  204.34951339046142
# Age Variance after 99 wala imputation:  951.7275570187188
# Age Variance after -1 wala imputation:  318.0896202624488
# Original Fare variable variance:  2448.1979137063163
# Fare Variance after 999 wala imputation:  47219.202652176304
# Fare Variance after -1 wala imputation:  2378.5676784883494

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
X1_train['Age'].plot(kind='kde', ax=ax)

# variable imputed with the median
X1_train['Age_99'].plot(kind='kde', ax=ax, color='red')

# variable imputed with the mean
X1_train['Age_minus1'].plot(kind='kde', ax=ax, color='green')

# add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
X1_train['Fare'].plot(kind='kde', ax=ax)

# variable imputed with the median
X1_train['Fare_999'].plot(kind='kde', ax=ax, color='red')

# variable imputed with the mean
X1_train['Fare_minus1'].plot(kind='kde', ax=ax, color='green')

# add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
X1_train.cov()
# Out:
#                     Age         Fare     Family      Age_99  Age_minus1  \
# Age          204.349513    70.719262  -6.498901  204.349513  204.349513
# Fare          70.719262  2448.197914  17.258917 -101.671097  125.558364
# Family        -6.498901    17.258917   2.735252   -7.387287   -4.149246
# Age_99       204.349513  -101.671097  -7.387287  951.727557 -189.535540
# Age_minus1   204.349513   125.558364  -4.149246 -189.535540  318.089620
# Fare_999     162.793430  2448.197914  11.528625 -159.931663  257.379887
# Fare_minus1   63.321188  2448.197914  16.553989  -94.317400  114.394141
#
#                  Fare_999  Fare_minus1
# Age            162.793430    63.321188
# Fare          2448.197914  2448.197914
# Family          11.528625    16.553989
# Age_99        -159.931663   -94.317400
# Age_minus1     257.379887   114.394141
# Fare_999     47219.202652   762.474982
# Fare_minus1    762.474982  2378.567678

# %%
X1_train.corr()
# Out:
#                   Age      Fare    Family    Age_99  Age_minus1  Fare_999  \
# Age          1.000000  0.092644 -0.299113  1.000000    1.000000  0.051179
# Fare         0.092644  1.000000  0.208268 -0.066273    0.142022  1.000000
# Family      -0.299113  0.208268  1.000000 -0.144787   -0.140668  0.032079
# Age_99       1.000000 -0.066273 -0.144787  1.000000   -0.344476 -0.023857
# Age_minus1   1.000000  0.142022 -0.140668 -0.344476    1.000000  0.066411
# Fare_999     0.051179  1.000000  0.032079 -0.023857    0.066411  1.000000
# Fare_minus1  0.084585  1.000000  0.205233 -0.062687    0.131514  0.071946
#
#              Fare_minus1
# Age             0.084585
# Fare            1.000000
# Family          0.205233
# Age_99         -0.062687
# Age_minus1      0.131514
# Fare_999        0.071946
# Fare_minus1     1.000000

# %% [markdown]
# -----
# -----
# ## using sklearn

# %%
X1_train,X1_test,y1_train,y1_test = train_test_split(X1,y1,test_size=0.2,random_state=2)

# %%
imputer3 = SimpleImputer(strategy='constant',fill_value=99)
imputer4 = SimpleImputer(strategy='constant',fill_value=999)

# %%
trf1 = ColumnTransformer([
    ('imputer3',imputer3,['Age']),
    ('imputer4',imputer4,['Fare'])
],remainder='passthrough')

# %%
trf1.fit(X1_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('imputer3',
#                                  SimpleImputer(fill_value=99,
#                                                strategy='constant'),
#                                  ['Age']),
#                                 ('imputer4',
#                                  SimpleImputer(fill_value=999,
#                                                strategy='constant'),
#                                  ['Fare'])])

# %%
trf1.named_transformers_['imputer3'].statistics_
# Out:
# array([99], dtype=object)

# %%
trf1.named_transformers_['imputer4'].statistics_
# Out:
# array([999], dtype=object)

# %%
X1_train = trf1.transform(X1_train)
X1_test = trf1.transform(X1_test)

# %%
X_train
# Out:
# array([[ 40.    ,  27.7208,   0.    ],
#        [  4.    ,  16.7   ,   2.    ],
#        [ 47.    ,   9.    ,   0.    ],
#        ...,
#        [ 71.    ,  49.5042,   0.    ],
#        [ 28.75  , 221.7792,   0.    ],
#        [ 28.75  ,  25.925 ,   0.    ]], shape=(712, 3))
