# %% [markdown]
# ## In this lecture we are going to understand a new library that will automate most of the EDA work that we do.
#
# -----
# ----

# %% [markdown]
# # Pandas Profiler

# %% [markdown]
# -----
# -----

# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:/ML/DataSet/Titanic_Dataset.csv')

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ----
# ----
#
# ## learn the code given below as it will directly do eda for you

# %%
from ydata_profiling import ProfileReport

# %%
prof = ProfileReport(df)

# %%
prof.to_file(output_file='Day22.html')      #this will make a file named Day22 in html format which is formed from the 
                                            #output from the working of ProfileReport on the given dataset
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 37.52it/s]

# %% [markdown]
# ----
# ----
#
# ## doing this will make a html file which can be opened at integrated browser and will show different analysis

# %% [markdown]
# -----
# -----

# %% [markdown]
# Examples to do my own
